# %% [markdown]
# # Library

# %%
# Data Wrangling
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# Visualization
import matplotlib.pylab as plt
from matplotlib import font_manager, rc
import seaborn as sns
# %matplotlib inline

# EDA
import klib

# Preprocessing & Feature Engineering
from sklearn.model_selection import train_test_split


# Hyperparameter Optimization
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold, cross_val_score

# Modeling
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import StratifiedKFold
from catboost import CatBoostRegressor, Pool
from xgboost import XGBRegressor

# Evaluation
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import RobustScaler

# Utility
import os
import time
import random
import warnings; warnings.filterwarnings("ignore")
from IPython.display import Image
import plotly 
import plotly.express as px

from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import shap
import pickle
from tqdm import tqdm
import platform
from itertools import combinations
from scipy.stats.mstats import gmean

import tensorflow as tf
from tensorflow import keras
import kerastuner as kt
from pycaret.regression import *

# %% [markdown]
# # 데이터 불러오기

# %%
# 학습용과 평가용(제출용) 데이터를 읽어들인다.
train = pd.read_csv('train_df.csv',encoding='cp949')
test = pd.read_csv('test_df.csv',encoding='cp949')

# 분석에 필요없는 INDEX 필드를 데이터에서 제거
#train_index = train['index']
#test_index = test['index']
#del train['index'], test['index']

# 학습용 정답 데이터를 읽는다.
target = pd.read_csv('train_df.csv',encoding='cp949').INVC_CONT

#submission 데이터를 읽는다.
submission = pd.read_csv('sample_submission.csv')

# %%
#시각화 설정
plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 15
# 사용자 운영체제 확인
import os
os.name

# 운영체제별 한글 폰트 설정
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
train.head()
# Out:
#    index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM  \
# 0      0  1129000014045300  5011000220046300          패션의류            상의
# 1      1  1135000009051200  5011000178037300         생활/건강          반려동물
# 2      2  1135000030093100  5011000265091400          패션의류        기타패션의류
# 3      3  1154500002014200  5011000315087400            식품           농산물
# 4      4  1165000021008300  5011000177051200            식품          가공식품
#
#    INVC_CONT
# 0          3
# 1          3
# 2          9
# 3         10
# 4          3

# %%
test.head()
# Out:
#    index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM
# 0  32000  5013000043028400  1165000021097200            식품           농산물
# 1  32001  5013000044016100  1154500002066400            식품           농산물
# 2  32002  5013000205030200  4139000102013200            식품           농산물
# 3  32003  5013000205030200  4221000040093400            식품           농산물
# 4  32004  5013000268011400  2726000004017100            식품           농산물

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32000 entries, 0 to 31999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          32000 non-null  int64
#  1   SEND_SPG_INNB  32000 non-null  int64
#  2   REC_SPG_INNB   32000 non-null  int64
#  3   DL_GD_LCLS_NM  32000 non-null  object
#  4   DL_GD_MCLS_NM  32000 non-null  object
#  5   INVC_CONT      32000 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4640 entries, 0 to 4639
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          4640 non-null   int64
#  1   SEND_SPG_INNB  4640 non-null   int64
#  2   REC_SPG_INNB   4640 non-null   int64
#  3   DL_GD_LCLS_NM  4640 non-null   object
#  4   DL_GD_MCLS_NM  4640 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 181.4+ KB

# %% [markdown]
# # Feature Engineering

# %%
train = pd.read_csv('train_all.csv')
test = pd.read_csv('test_all.csv')

# %%
train = pd.concat([train,target],axis=1)

# %%
train.head()
# Out:
#    index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM  \
# 0      0  1129000014045300  5011000220046300          패션의류            상의
# 1      1  1135000009051200  5011000178037300         생활/건강          반려동물
# 2      2  1135000030093100  5011000265091400          패션의류        기타패션의류
# 3      3  1154500002014200  5011000315087400            식품           농산물
# 4      4  1165000021008300  5011000177051200            식품          가공식품
#
#   SEND_SPG_NM SEND_SIGUNGU_NM SEND_REGION REC_SPG_NM REC_SIGUNGU_NM  \
# 0      다사6156             성북구          서울     다다1502            제주시
# 1      다사6163             노원구          서울     다다1903            제주시
# 2      다사6158             노원구          서울     다다1001            제주시
# 3      다사4541             금천구          서울     다다0600            제주시
# 4      다사5942             서초구          서울     다다1803            제주시
#
#   REC_REGION  INVC_CONT
# 0         제주          3
# 1         제주          3
# 2         제주          9
# 3         제주         10
# 4         제주          3

# %%
train.corr()
#유일한 수치형 변수인 SEND_SPG_INNB와 REC_SPG_INNB가 INVC_CONT와 상관관계가 없다...
#말그대로 택배를 보내는 곳과 받는 곳의 격자공간고유번호를 수치로 표현한 것이기 때문이라 생각
#그러나 SEND_SPG_INNB와와 REC_SPG_INNB사이에는 상관관계가 다소 존재
# Out:
#                   index  SEND_SPG_INNB  REC_SPG_INNB  INVC_CONT
# index          1.000000       0.008242     -0.002749  -0.006936
# SEND_SPG_INNB  0.008242       1.000000     -0.375218  -0.058702
# REC_SPG_INNB  -0.002749      -0.375218      1.000000   0.063201
# INVC_CONT     -0.006936      -0.058702      0.063201   1.000000

# %%
train.sort_values(by='SEND_SPG_INNB')[['SEND_SPG_INNB','SEND_SIGUNGU_NM']]
#격자공간고유번호는 제주도를 기준으로 위도가 상승할수록 증가하는 경향이 있음
# Out:
#           SEND_SPG_INNB SEND_SIGUNGU_NM
# 16521  1111000015066100             종로구
# 8458   1111000017015300             종로구
# 5187   1111000019090400             종로구
# 28455  1111000019090400             종로구
# 7565   1111000019090400             종로구
# ...                 ...             ...
# 9067   5013000946025300            서귀포시
# 6405   5013000946029100            서귀포시
# 16799  5013000946029100            서귀포시
# 22009  5013000946029100            서귀포시
# 14984  5013000957045100            서귀포시
#
# [32000 rows x 2 columns]

# %%
plt.figure(figsize=(10,10))

sns.barplot(x='DL_GD_LCLS_NM',y='INVC_CONT',data=train)
plt.title('대분류별 운송량')
plt.show()
#패션의류나 디지털/가전 대분류 품목의 운송량이 많다.

# %%
plt.figure(figsize=(25,20))

sns.barplot(x='DL_GD_MCLS_NM',y='INVC_CONT',data=train)
plt.title('중분류별 운송량')
plt.show()
#기타패션의류나 건강용품의 운송량이 많다.
#상의나 음반의 운송량이 적다.

# %%
plt.figure(figsize=(25,20))

sns.barplot(x='SEND_REGION',y='INVC_CONT',data=train)
plt.title('송신지역별 운송량')
plt.show()

# %%
plt.figure(figsize=(25,20))

sns.barplot(x='REC_REGION',y='INVC_CONT',data=train)
plt.title('수신지역별 운송량')
plt.show()

# %%
plt.figure(figsize=(10,10))
x = train['INVC_CONT']
sns.kdeplot(x)
plt.title("운송량")
plt.show()

# %%
klib.dist_plot(train['INVC_CONT'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='INVC_CONT', ylabel='Density'>

# %%
print(train['INVC_CONT'].describe())
#값이 작은쪽으로 치우친 분포를 보임
#정규화가 필요할 수도 있다고 생각
# Out:
# count    32000.000000
# mean         4.767875
# std          5.752122
# min          3.000000
# 25%          3.000000
# 50%          3.000000
# 75%          5.000000
# max        239.000000
# Name: INVC_CONT, dtype: float64

# %%
train['SEND_SPG_INNB'].value_counts()
#5011000078068400가 상대적으로 많음
# Out:
# 5011000078068400    4227
# 5013000610049100    1994
# 5013000731055200    1335
# 5011000137030100    1206
# 5013000821028200     773
#                     ...
# 1150000024078300       1
# 4613000577098400       1
# 5013000668056100       1
# 4150000213070400       1
# 4128500029019300       1
# Name: SEND_SPG_INNB, Length: 3684, dtype: int64

# %%
train['SEND_SPG_INNB_RATIO'] = train.groupby(['SEND_SPG_INNB'])['index'].transform('count') / train.shape[0]

# %%
train['REC_SPG_INNB'].value_counts()
# Out:
# 5011000543041100    31
# 5011000596012200    27
# 5013000635005300    24
# 5011000318044100    20
# 5011000544072300    20
#                     ..
# 4161000245010100     1
# 2811000051074100     1
# 1123000006020100     1
# 1168000015051100     1
# 1130500018038200     1
# Name: REC_SPG_INNB, Length: 27826, dtype: int64

# %%
train['REC_SPG_INNB_RATIO'] = train.groupby(['REC_SPG_INNB'])['index'].transform('count') / train.shape[0]

# %%
train['DL_GD_LCLS_NM'].value_counts()
#식품이 가장 많고 운송량도 균일함
# Out:
# 식품        27738
# 생활/건강      2020
# 여행/문화      1192
# 패션의류        582
# 디지털/가전      241
# 화장품/미용      227
# Name: DL_GD_LCLS_NM, dtype: int64

# %%
train['DL_GD_LCLS_NM_RATIO'] = train.groupby(['DL_GD_LCLS_NM'])['index'].transform('count') / train.shape[0]

# %%
train['DL_GD_MCLS_NM'].value_counts()
#농산물이 가장 많고 운송량도 균일함
# Out:
# 농산물          22162
# 문화컨텐츠         1192
# 음료            1126
# 수산             931
# 가공식품           923
# 기타식품           766
# 건강식품           651
# 음반             635
# 축산             418
# 냉동/간편조리식품      413
# 반려동물           358
# 과자             348
# 생활용품           343
# 주방용품           328
# 상의             321
# 기타패션의류         261
# 기타디지털/가전       241
# 스킨케어           227
# 문구/사무용품        180
# 건강용품           176
# Name: DL_GD_MCLS_NM, dtype: int64

# %%
train['DL_GD_MCLS_NM_RATIO'] = train.groupby(['DL_GD_MCLS_NM'])['index'].transform('count') / train.shape[0]

# %%
train['SEND_SPG_NM'].value_counts()
# Out:
# 다다3007    4254
# 다나1778    2011
# 다나2176    1527
# 다다1804    1232
# 다나1174     792
#           ...
# 다사2163       1
# 다사6630       1
# 다나3282       1
# 다다4102       1
# 다바4399       1
# Name: SEND_SPG_NM, Length: 2069, dtype: int64

# %%
train['SEND_SPG_NM_RATIO'] = train.groupby(['SEND_SPG_NM'])['index'].transform('count') / train.shape[0]

# %%
train['SEND_SIGUNGU_NM'].value_counts()
# Out:
# 제주시          14003
# 서귀포시         11341
# 파주시           1203
# 화성시            395
# 군포시            363
# 남양주시           272
# 이천시            270
# 용인시처인구         241
# 김포시            209
# 용산구            175
# 대덕구            166
# 광주시            146
# 북구             117
# 고양시일산동구        115
# 서구             101
# 평택시             81
# 구로구             78
# 성북구             77
# 부천시오정구          76
# 중구              74
# 강서구             73
# 서초구             70
# 안산시단원구          56
# 전주시덕진구          50
# 오산시             49
# 당진시             47
# 강남구             47
# 포천시             45
# 동구              44
# 영등포구            43
# 익산시             43
# 하남시             42
# 안산시상록구          42
# 남구              39
# 유성구             38
# 아산시             37
# 청주시흥덕구          37
# 노원구             37
# 안성시             35
# 종로구             32
# 원주시             32
# 청원군             31
# 양주시             31
# 성동구             30
# 고양시덕양구          29
# 음성군             29
# 청주시상당구          28
# 금천구             28
# 고성군             28
# 송파구             28
# 강동구             25
# 달서구             25
# 연천군             25
# 해운대구            23
# 성남시 분당구         22
# 광명시             21
# 사하구             21
# 시흥시             20
# 사상구             19
# 용인시기흥구          19
# 울주군             19
# 춘천시             19
# 창원시 마산합포구       18
# 중랑구             18
# 안양시동안구          18
# 성남시 중원구         17
# 김천시             17
# 청송군             17
# 남동구             16
# 안동시             16
# 천안시동남구          15
# 부산진구            15
# 포항시 북구          15
# 보령시             14
# 칠곡군             14
# 상주시             14
# 금산군             14
# 고창군             14
# 장성군             14
# 담양군             14
# 나주시             14
# 관악구             13
# 광진구             13
# 마포구             13
# 달성군             13
# 금정구             12
# 의왕시             12
# 양천구             12
# 양산시             12
# 남원시             11
# 구리시             11
# 영동군             11
# 충주시             11
# 부천시원미구          11
# 수영구             10
# 제천시             10
# 강릉시             10
# 통영시             10
# 수원시 권선구         10
# 천안시서북구          10
# 무안군             10
# 구미시             10
# 수원시 영통구         10
# 고양시일산서구          9
# 서산시              9
# 김해시              9
# 포항시 남구           9
# 동대문구             9
# 문경시              9
# 공주시              9
# 여수시              9
# 도봉구              9
# 증평군              9
# 동래구              8
# 전주시완산구           8
# 연제구              8
# 해남군              8
# 홍성군              8
# 김제시              8
# 계양구              8
# 부평구              7
# 창원시 의창구          7
# 광산구              7
# 함안군              7
# 경주시              7
# 경산시              7
# 은평구              7
# 보은군              7
# 강북구              7
# 용인시수지구           7
# 의정부시             7
# 수원시 팔달구          6
# 서대문구             6
# 안양시만안구           6
# 영주시              6
# 수성구              6
# 동해시              6
# 순천시              6
# 진천군              6
# 영광군              6
# 광양시              6
# 영천시              5
# 청도군              5
# 기장군              5
# 목포시              5
# 인제군              5
# 동작구              5
# 진주시              5
# 강진군              5
# 장흥군              5
# 영암군              5
# 연수구              5
# 강화군              5
# 순창군              5
# 진안군              5
# 함양군              4
# 창원시 진해구          4
# 세종특별자치시          4
# 완주군              4
# 거창군              4
# 함평군              4
# 밀양시              4
# 철원군              4
# 논산시              4
# 부천시소사구           4
# 군위군              4
# 부안군              4
# 영양군              4
# 동두천시             4
# 보성군              3
# 의성군              3
# 정읍시              3
# 산청군              3
# 성남시 수정구          3
# 임실군              3
# 횡성군              3
# 예천군              3
# 수원시 장안구          3
# 완도군              3
# 여주시              3
# 사천시              3
# 옥천군              3
# 창원시 성산구          3
# 고흥군              3
# 영도구              2
# 남해군              2
# 영월군              2
# 괴산군              2
# 고령군              2
# 평창군              2
# 무주군              2
# 신안군              2
# 계룡시              2
# 태안군              2
# 서천군              2
# 양구군              2
# 예산군              2
# 군산시              2
# 삼척시              2
# 홍천군              2
# 합천군              2
# 성주군              2
# 과천시              1
# 영덕군              1
# 장수군              1
# 가평군              1
# 봉화군              1
# 화순군              1
# 정선군              1
# 속초시              1
# 태백시              1
# 곡성군              1
# Name: SEND_SIGUNGU_NM, dtype: int64

# %%
train['SEND_SIGUNGU_NM_RATIO'] = train.groupby(['SEND_SIGUNGU_NM'])['index'].transform('count') / train.shape[0]

# %%
train['SEND_REGION'].value_counts()
# Out:
# 제주      25344
# 경기도      3950
# 서울        859
# 인천        363
# 부산        187
# 대구        185
# 충청북도      184
# 충청남도      175
# 경상북도      171
# 전라북도      163
# 전라남도      124
# 강원도       118
# 경상남도       99
# 광주         46
# 울산         28
# 세종          4
# Name: SEND_REGION, dtype: int64

# %%
train['SEND_REGION_RATIO'] = train.groupby(['SEND_REGION'])['index'].transform('count') / train.shape[0]

# %%
train['REC_SPG_NM'].value_counts()
# Out:
# 다나0599    304
# 다나0699    215
# 다다0901    201
# 다다0600    199
# 다다0500    182
#          ...
# 다사5884      1
# 라사1721      1
# 다사8014      1
# 다바5292      1
# 라아4314      1
# Name: REC_SPG_NM, Length: 7722, dtype: int64

# %%
train['REC_SPG_NM_RATIO'] = train.groupby(['REC_SPG_NM'])['index'].transform('count') / train.shape[0]

# %%
train['REC_SIGUNGU_NM'].value_counts()
# Out:
# 제주시          5185
# 서귀포시         1648
# 서구            701
# 북구            563
# 남구            554
# 화성시           487
# 중구            444
# 강남구           416
# 동구            384
# 송파구           361
# 강서구           360
# 남양주시          336
# 성남시 분당구       295
# 서초구           295
# 남동구           283
# 시흥시           281
# 영등포구          276
# 마포구           261
# 평택시           261
# 노원구           254
# 김해시           252
# 용인시기흥구        251
# 의정부시          251
# 파주시           242
# 고양시덕양구        242
# 김포시           230
# 달서구           227
# 전주시완산구        221
# 부천시원미구        221
# 아산시           219
# 연수구           214
# 수원시 영통구       213
# 관악구           212
# 양천구           208
# 해운대구          208
# 부평구           207
# 광명시           206
# 고양시일산동구       204
# 안산시단원구        204
# 청주시흥덕구        203
# 수성구           193
# 천안시서북구        193
# 전주시덕진구        192
# 안양시동안구        191
# 성북구           189
# 유성구           184
# 수원시 권선구       183
# 구로구           183
# 세종특별자치시       183
# 구미시           180
# 광주시           176
# 서대문구          176
# 동대문구          175
# 원주시           173
# 강동구           172
# 용인시수지구        171
# 부산진구          171
# 성동구           169
# 군포시           168
# 광산구           168
# 은평구           162
# 계양구           162
# 동작구           157
# 여수시           155
# 용산구           154
# 익산시           153
# 종로구           153
# 중랑구           152
# 안산시상록구        152
# 수원시 장안구       152
# 춘천시           147
# 용인시처인구        142
# 양산시           142
# 고양시일산서구       141
# 천안시동남구        140
# 양주시           139
# 사하구           139
# 광진구           136
# 안성시           134
# 창원시 의창구       131
# 이천시           131
# 진주시           126
# 경주시           126
# 도봉구           125
# 목포시           124
# 거제시           123
# 하남시           123
# 울주군           121
# 경산시           118
# 달성군           118
# 동래구           117
# 성남시 수정구       115
# 강릉시           113
# 청주시상당구        113
# 순천시           113
# 안양시만안구        109
# 포항시 남구        107
# 오산시           106
# 군산시           106
# 금천구           103
# 금정구           103
# 강북구           101
# 포항시 북구        100
# 창원시 성산구        99
# 당진시            99
# 서산시            98
# 연제구            98
# 청원군            92
# 사상구            92
# 구리시            90
# 대덕구            90
# 충주시            88
# 포천시            87
# 수원시 팔달구        83
# 성남시 중원구        83
# 홍성군            80
# 창원시 진해구        78
# 의왕시            77
# 광양시            76
# 속초시            74
# 기장군            72
# 제천시            72
# 부천시소사구         71
# 안동시            68
# 보령시            67
# 부천시오정구         65
# 수영구            65
# 영도구            63
# 창원시 마산회원구      62
# 여주시            60
# 공주시            57
# 통영시            56
# 김천시            55
# 무안군            54
# 양평군            53
# 영주시            52
# 창원시 마산합포구      52
# 논산시            52
# 나주시            50
# 진천군            50
# 삼척시            49
# 홍천군            47
# 사천시            45
# 예산군            44
# 밀양시            43
# 동해시            43
# 과천시            42
# 칠곡군            42
# 상주시            41
# 정읍시            41
# 영천시            39
# 남원시            39
# 완주군            38
# 해남군            37
# 김제시            36
# 가평군            35
# 의성군            35
# 부여군            34
# 문경시            34
# 화순군            32
# 횡성군            32
# 음성군            32
# 영암군            31
# 옥천군            31
# 거창군            31
# 강화군            29
# 태안군            29
# 고성군            29
# 동두천시           29
# 연천군            29
# 평창군            28
# 철원군            27
# 서천군            27
# 태백시            27
# 정선군            27
# 보성군            26
# 함안군            26
# 부안군            24
# 금산군            23
# 영동군            23
# 영광군            22
# 단양군            22
# 영월군            21
# 창녕군            21
# 진도군            21
# 장성군            20
# 성주군            20
# 계룡시            20
# 청도군            19
# 고창군            19
# 장흥군            19
# 인제군            19
# 증평군            19
# 순창군            18
# 함양군            18
# 울진군            17
# 예천군            17
# 합천군            17
# 양양군            17
# 남해군            17
# 하동군            16
# 고흥군            16
# 영양군            15
# 신안군            15
# 진안군            15
# 산청군            15
# 구례군            15
# 임실군            14
# 영덕군            14
# 장수군            14
# 완도군            14
# 담양군            13
# 보은군            13
# 함평군            13
# 무주군            12
# 봉화군            12
# 의령군            12
# 괴산군            12
# 청양군            11
# 강진군            11
# 고령군            11
# 양구군             9
# 곡성군             8
# 청송군             7
# 군위군             7
# 화천군             7
# 옹진군             4
# 울릉군             2
# Name: REC_SIGUNGU_NM, dtype: int64

# %%
train['REC_SIGUNGU_NM_RATIO'] = train.groupby(['REC_SIGUNGU_NM'])['index'].transform('count') / train.shape[0]

# %%
train['REC_REGION'].value_counts()
# Out:
# 경기도     7061
# 제주      6833
# 서울      4984
# 인천      2101
# 부산      1548
# 경상남도    1397
# 충청남도    1193
# 경상북도    1138
# 전라북도     942
# 대구       911
# 전라남도     885
# 강원도      874
# 충청북도     770
# 광주       636
# 울산       544
# 세종       183
# Name: REC_REGION, dtype: int64

# %%
train['REC_REGION_RATIO'] = train.groupby(['REC_REGION'])['index'].transform('count') / train.shape[0]

# %%
train
# Out:
#        index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM  \
# 0          0  1129000014045300  5011000220046300          패션의류            상의
# 1          1  1135000009051200  5011000178037300         생활/건강          반려동물
# 2          2  1135000030093100  5011000265091400          패션의류        기타패션의류
# 3          3  1154500002014200  5011000315087400            식품           농산물
# 4          4  1165000021008300  5011000177051200            식품          가공식품
# ...      ...               ...               ...           ...           ...
# 31995  31995  5011001060063300  2635000026053400            식품           농산물
# 31996  31996  5011001095042400  1168000017002200            식품          기타식품
# 31997  31997  5011001108036200  4119700008012100            식품           농산물
# 31998  31998  5011001115011400  1132000015085100            식품           농산물
# 31999  31999  5011001116066400  4719000594022400            식품           농산물
#
#       SEND_SPG_NM SEND_SIGUNGU_NM SEND_REGION REC_SPG_NM REC_SIGUNGU_NM  \
# 0          다사6156             성북구          서울     다다1502            제주시
# 1          다사6163             노원구          서울     다다1903            제주시
# 2          다사6158             노원구          서울     다다1001            제주시
# 3          다사4541             금천구          서울     다다0600            제주시
# 4          다사5942             서초구          서울     다다1803            제주시
# ...           ...             ...         ...        ...            ...
# 31995      나나8483             제주시          제주     마라4789           해운대구
# 31996      나나8581             제주시          제주     다사6044            강남구
# 31997      나나8380             제주시          제주     다사3841         부천시소사구
# 31998      나나7779             제주시          제주     다사5861            도봉구
# 31999      나나7879             제주시          제주     라마8488            구미시
#
#       REC_REGION  INVC_CONT  SEND_SPG_INNB_RATIO  REC_SPG_INNB_RATIO  \
# 0             제주          3             0.002094            0.000063
# 1             제주          3             0.000844            0.000031
# 2             제주          9             0.000063            0.000031
# 3             제주         10             0.000031            0.000313
# 4             제주          3             0.000031            0.000063
# ...          ...        ...                  ...                 ...
# 31995         부산          6             0.002344            0.000031
# 31996         서울          5             0.000562            0.000031
# 31997        경기도          9             0.001187            0.000031
# 31998         서울          3             0.000188            0.000031
# 31999       경상북도          5             0.001406            0.000031
#
#        DL_GD_LCLS_NM_RATIO  DL_GD_MCLS_NM_RATIO  SEND_SPG_NM_RATIO  \
# 0                 0.018187             0.010031           0.002094
# 1                 0.063125             0.011187           0.000844
# 2                 0.018187             0.008156           0.000125
# 3                 0.866812             0.692562           0.000344
# 4                 0.866812             0.028844           0.000188
# ...                    ...                  ...                ...
# 31995             0.866812             0.692562           0.002375
# 31996             0.866812             0.023938           0.001219
# 31997             0.866812             0.692562           0.001563
# 31998             0.866812             0.692562           0.000875
# 31999             0.866812             0.692562           0.001594
#
#        SEND_SIGUNGU_NM_RATIO  SEND_REGION_RATIO  REC_SPG_NM_RATIO  \
# 0                   0.002406           0.026844          0.000906
# 1                   0.001156           0.026844          0.000031
# 2                   0.001156           0.026844          0.004281
# 3                   0.000875           0.026844          0.006219
# 4                   0.002188           0.026844          0.000219
# ...                      ...                ...               ...
# 31995               0.437594           0.792000          0.000250
# 31996               0.437594           0.792000          0.000656
# 31997               0.437594           0.792000          0.000406
# 31998               0.437594           0.792000          0.000344
# 31999               0.437594           0.792000          0.000094
#
#        REC_SIGUNGU_NM_RATIO  REC_REGION_RATIO
# 0                  0.162031          0.213531
# 1                  0.162031          0.213531
# 2                  0.162031          0.213531
# 3                  0.162031          0.213531
# 4                  0.162031          0.213531
# ...                     ...               ...
# 31995              0.006500          0.048375
# 31996              0.013000          0.155750
# 31997              0.002219          0.220656
# 31998              0.003906          0.155750
# 31999              0.005625          0.035562
#
# [32000 rows x 22 columns]

# %%
ratio1 = train[['SEND_SPG_INNB','SEND_SPG_INNB_RATIO']]
ratio1 = ratio1.drop_duplicates()
ratio2 = train[['REC_SPG_INNB','REC_SPG_INNB_RATIO']]
ratio2 = ratio2.drop_duplicates()
ratio3 = train[['DL_GD_LCLS_NM','DL_GD_LCLS_NM_RATIO']]
ratio3 = ratio3.drop_duplicates()
ratio4 = train[['DL_GD_MCLS_NM','DL_GD_MCLS_NM_RATIO']]
ratio4 = ratio4.drop_duplicates()
ratio5 = train[['SEND_SPG_NM','SEND_SPG_NM_RATIO']]
ratio5 = ratio5.drop_duplicates()
ratio6 = train[['SEND_SIGUNGU_NM','SEND_SIGUNGU_NM_RATIO']]
ratio6 = ratio6.drop_duplicates()
ratio7 = train[['SEND_REGION','SEND_REGION_RATIO']]
ratio7 = ratio7.drop_duplicates()
ratio8 = train[['REC_SPG_NM','REC_SPG_NM_RATIO']]
ratio8 = ratio8.drop_duplicates()
ratio9 = train[['REC_SIGUNGU_NM','REC_SIGUNGU_NM_RATIO']]
ratio9 = ratio9.drop_duplicates()
ratio10 = train[['REC_REGION','REC_REGION_RATIO']]
ratio10 = ratio10.drop_duplicates()

# %%
test = pd.merge(test, ratio1, how='left', on = 'SEND_SPG_INNB')
test = pd.merge(test, ratio2, how='left', on = 'REC_SPG_INNB')
test = pd.merge(test, ratio3, how='left', on = 'DL_GD_LCLS_NM')
test = pd.merge(test, ratio4, how='left', on = 'DL_GD_MCLS_NM')
test = pd.merge(test, ratio5, how='left', on = 'SEND_SPG_NM')
test = pd.merge(test, ratio6, how='left', on = 'SEND_SIGUNGU_NM')
test = pd.merge(test, ratio7, how='left', on = 'SEND_REGION')
test = pd.merge(test, ratio8, how='left', on = 'REC_SPG_NM')
test = pd.merge(test, ratio9, how='left', on = 'REC_SIGUNGU_NM')
test = pd.merge(test, ratio10, how='left', on ='REC_REGION')

# %%
train['SAME_SPG'] = train['SEND_SPG_NM'] == train['REC_SPG_NM']
train['SAME_SPG'] = train['SAME_SPG'].astype(int)
train['SAME_SPG']
#SEND_SPG_NM 과 REC_SPG_NM이 같은 지 여부
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31995    0
# 31996    0
# 31997    0
# 31998    0
# 31999    0
# Name: SAME_SPG, Length: 32000, dtype: int32

# %%
test['SAME_SPG'] = test['SEND_SPG_NM'] == test['REC_SPG_NM']
test['SAME_SPG'] = test['SAME_SPG'].astype(int)
test['SAME_SPG']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4635    0
# 4636    0
# 4637    0
# 4638    0
# 4639    0
# Name: SAME_SPG, Length: 4640, dtype: int32

# %%
train['SAME_SIGUNGU'] = train['SEND_SIGUNGU_NM'] == train['REC_SIGUNGU_NM']
train['SAME_SIGUNGU'] = train['SAME_SIGUNGU'].astype(int)
train['SAME_SIGUNGU']
#SEND_SIGUNGU_NM 과 REC_SIGUNGU_NM 같은 지 여부
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31995    0
# 31996    0
# 31997    0
# 31998    0
# 31999    0
# Name: SAME_SIGUNGU, Length: 32000, dtype: int32

# %%
test['SAME_SIGUNGU'] = test['SEND_SIGUNGU_NM'] == test['REC_SIGUNGU_NM']
test['SAME_SIGUNGU'] = test['SAME_SIGUNGU'].astype(int)
test['SAME_SIGUNGU']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4635    0
# 4636    0
# 4637    0
# 4638    0
# 4639    0
# Name: SAME_SIGUNGU, Length: 4640, dtype: int32

# %%
train['SAME_REGION'] = train['SEND_REGION'] == train['REC_REGION']
train['SAME_REGION'] = train['SAME_REGION'].astype(int)
train['SAME_REGION']
#SEND_REGION 과 REC_REGION 같은 지 여부
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31995    0
# 31996    0
# 31997    0
# 31998    0
# 31999    0
# Name: SAME_REGION, Length: 32000, dtype: int32

# %%
test['SAME_REGION'] = test['SEND_REGION'] == test['REC_REGION']
test['SAME_REGION'] = test['SAME_REGION'].astype(int)
test['SAME_REGION']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4635    0
# 4636    0
# 4637    0
# 4638    0
# 4639    0
# Name: SAME_REGION, Length: 4640, dtype: int32

# %%
train['SAME_INNB'] = train['SEND_SPG_INNB'] == train['REC_SPG_INNB']
train['SAME_INNB'] = train['SAME_INNB'].astype(int)
train['SAME_INNB']
#SEND_SPG_INNB 과 REC_SPG_INNB 같은 지 여부
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31995    0
# 31996    0
# 31997    0
# 31998    0
# 31999    0
# Name: SAME_INNB, Length: 32000, dtype: int32

# %%
test['SAME_INNB'] = test['SEND_SPG_INNB'] == test['REC_SPG_INNB']
test['SAME_INNB'] = test['SAME_INNB'].astype(int)
test['SAME_INNB']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4635    0
# 4636    0
# 4637    0
# 4638    0
# 4639    0
# Name: SAME_INNB, Length: 4640, dtype: int32

# %%
train['SAME_TOTAL'] = train['SAME_SPG'] + train['SAME_SIGUNGU'] + train['SAME_REGION'] + train['SAME_INNB'] 
train['SAME_TOTAL'] = train['SAME_TOTAL'].astype(int)
train['SAME_TOTAL']
#여부 변수 총합
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31995    0
# 31996    0
# 31997    0
# 31998    0
# 31999    0
# Name: SAME_TOTAL, Length: 32000, dtype: int32

# %%
test['SAME_TOTAL'] = test['SAME_SPG'] + test['SAME_SIGUNGU'] + test['SAME_REGION'] + test['SAME_INNB'] 
test['SAME_TOTAL'] = test['SAME_TOTAL'].astype(int)
test['SAME_TOTAL']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4635    0
# 4636    0
# 4637    0
# 4638    0
# 4639    0
# Name: SAME_TOTAL, Length: 4640, dtype: int32

# %%
train
# Out:
#        index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM  \
# 0          0  1129000014045300  5011000220046300          패션의류            상의
# 1          1  1135000009051200  5011000178037300         생활/건강          반려동물
# 2          2  1135000030093100  5011000265091400          패션의류        기타패션의류
# 3          3  1154500002014200  5011000315087400            식품           농산물
# 4          4  1165000021008300  5011000177051200            식품          가공식품
# ...      ...               ...               ...           ...           ...
# 31995  31995  5011001060063300  2635000026053400            식품           농산물
# 31996  31996  5011001095042400  1168000017002200            식품          기타식품
# 31997  31997  5011001108036200  4119700008012100            식품           농산물
# 31998  31998  5011001115011400  1132000015085100            식품           농산물
# 31999  31999  5011001116066400  4719000594022400            식품           농산물
#
#       SEND_SPG_NM SEND_SIGUNGU_NM SEND_REGION REC_SPG_NM REC_SIGUNGU_NM  \
# 0          다사6156             성북구          서울     다다1502            제주시
# 1          다사6163             노원구          서울     다다1903            제주시
# 2          다사6158             노원구          서울     다다1001            제주시
# 3          다사4541             금천구          서울     다다0600            제주시
# 4          다사5942             서초구          서울     다다1803            제주시
# ...           ...             ...         ...        ...            ...
# 31995      나나8483             제주시          제주     마라4789           해운대구
# 31996      나나8581             제주시          제주     다사6044            강남구
# 31997      나나8380             제주시          제주     다사3841         부천시소사구
# 31998      나나7779             제주시          제주     다사5861            도봉구
# 31999      나나7879             제주시          제주     라마8488            구미시
#
#       REC_REGION  INVC_CONT  SEND_SPG_INNB_RATIO  REC_SPG_INNB_RATIO  \
# 0             제주          3             0.002094            0.000063
# 1             제주          3             0.000844            0.000031
# 2             제주          9             0.000063            0.000031
# 3             제주         10             0.000031            0.000313
# 4             제주          3             0.000031            0.000063
# ...          ...        ...                  ...                 ...
# 31995         부산          6             0.002344            0.000031
# 31996         서울          5             0.000562            0.000031
# 31997        경기도          9             0.001187            0.000031
# 31998         서울          3             0.000188            0.000031
# 31999       경상북도          5             0.001406            0.000031
#
#        DL_GD_LCLS_NM_RATIO  DL_GD_MCLS_NM_RATIO  SEND_SPG_NM_RATIO  \
# 0                 0.018187             0.010031           0.002094
# 1                 0.063125             0.011187           0.000844
# 2                 0.018187             0.008156           0.000125
# 3                 0.866812             0.692562           0.000344
# 4                 0.866812             0.028844           0.000188
# ...                    ...                  ...                ...
# 31995             0.866812             0.692562           0.002375
# 31996             0.866812             0.023938           0.001219
# 31997             0.866812             0.692562           0.001563
# 31998             0.866812             0.692562           0.000875
# 31999             0.866812             0.692562           0.001594
#
#        SEND_SIGUNGU_NM_RATIO  SEND_REGION_RATIO  REC_SPG_NM_RATIO  \
# 0                   0.002406           0.026844          0.000906
# 1                   0.001156           0.026844          0.000031
# 2                   0.001156           0.026844          0.004281
# 3                   0.000875           0.026844          0.006219
# 4                   0.002188           0.026844          0.000219
# ...                      ...                ...               ...
# 31995               0.437594           0.792000          0.000250
# 31996               0.437594           0.792000          0.000656
# 31997               0.437594           0.792000          0.000406
# 31998               0.437594           0.792000          0.000344
# 31999               0.437594           0.792000          0.000094
#
#        REC_SIGUNGU_NM_RATIO  REC_REGION_RATIO  SAME_SPG  SAME_SIGUNGU  \
# 0                  0.162031          0.213531         0             0
# 1                  0.162031          0.213531         0             0
# 2                  0.162031          0.213531         0             0
# 3                  0.162031          0.213531         0             0
# 4                  0.162031          0.213531         0             0
# ...                     ...               ...       ...           ...
# 31995              0.006500          0.048375         0             0
# 31996              0.013000          0.155750         0             0
# 31997              0.002219          0.220656         0             0
# 31998              0.003906          0.155750         0             0
# 31999              0.005625          0.035562         0             0
#
#        SAME_REGION  SAME_INNB  SAME_TOTAL
# 0                0          0           0
# 1                0          0           0
# 2                0          0           0
# 3                0          0           0
# 4                0          0           0
# ...            ...        ...         ...
# 31995            0          0           0
# 31996            0          0           0
# 31997            0          0           0
# 31998            0          0           0
# 31999            0          0           0
#
# [32000 rows x 27 columns]

# %%
test
# Out:
#       index     SEND_SPG_INNB      REC_SPG_INNB DL_GD_LCLS_NM DL_GD_MCLS_NM  \
# 0     32000  5013000043028400  1165000021097200            식품           농산물
# 1     32001  5013000044016100  1154500002066400            식품           농산물
# 2     32002  5013000205030200  4139000102013200            식품           농산물
# 3     32003  5013000205030200  4221000040093400            식품           농산물
# 4     32004  5013000268011400  2726000004017100            식품           농산물
# ...     ...               ...               ...           ...           ...
# 4635  36635  5013000858004400  4725000719072200            식품           농산물
# 4636  36636  5013000870018300  2826000106075300            식품           농산물
# 4637  36637  5013000897086300  4311100034004300            식품           농산물
# 4638  36638  5013000902065100  4145000013011200            식품           농산물
# 4639  36639  5013000926078200  2714000174062400            식품           농산물
#
#      SEND_SPG_NM SEND_SIGUNGU_NM SEND_REGION REC_SPG_NM REC_SIGUNGU_NM  \
# 0         다나4294            서귀포시          제주     다사5942            서초구
# 1         다나4394            서귀포시          제주     다사4541            금천구
# 2         다나4187            서귀포시          제주     다사3029            시흥시
# 3         다나4187            서귀포시          제주     라아9121            속초시
# 4         다나3285            서귀포시          제주     마마0564            수성구
# ...          ...             ...         ...        ...            ...
# 4635      다나0473            서귀포시          제주     라바5923            상주시
# 4636      다나1673            서귀포시          제주     다사2548             서구
# 4637      나나9472            서귀포시          제주     다바9950         청주시상당구
# 4638      다나0472            서귀포시          제주     다사7250            하남시
# 4639      나나8371            서귀포시          제주     마마1164             동구
#
#      REC_REGION  SEND_SPG_INNB_RATIO  REC_SPG_INNB_RATIO  DL_GD_LCLS_NM_RATIO  \
# 0            서울             0.000906                 NaN             0.866812
# 1            서울             0.000562            0.000031             0.866812
# 2           경기도             0.001125            0.000031             0.866812
# 3           강원도             0.001125                 NaN             0.866812
# 4            대구             0.000281                 NaN             0.866812
# ...         ...                  ...                 ...                  ...
# 4635       경상북도             0.001594            0.000031             0.866812
# 4636         인천             0.000719                 NaN             0.866812
# 4637       충청북도             0.000438                 NaN             0.866812
# 4638        경기도             0.000969                 NaN             0.866812
# 4639         대구             0.000406                 NaN             0.866812
#
#       DL_GD_MCLS_NM_RATIO  SEND_SPG_NM_RATIO  SEND_SIGUNGU_NM_RATIO  \
# 0                0.692562           0.001937               0.354406
# 1                0.692562           0.000562               0.354406
# 2                0.692562           0.001813               0.354406
# 3                0.692562           0.001813               0.354406
# 4                0.692562           0.000344               0.354406
# ...                   ...                ...                    ...
# 4635             0.692562           0.004469               0.354406
# 4636             0.692562           0.001094               0.354406
# 4637             0.692562           0.000469               0.354406
# 4638             0.692562           0.002188               0.354406
# 4639             0.692562           0.001219               0.354406
#
#       SEND_REGION_RATIO  REC_SPG_NM_RATIO  REC_SIGUNGU_NM_RATIO  \
# 0                 0.792          0.000250              0.009219
# 1                 0.792          0.000188              0.003219
# 2                 0.792          0.000469              0.008781
# 3                 0.792               NaN              0.002312
# 4                 0.792          0.000063              0.006031
# ...                 ...               ...                   ...
# 4635              0.792          0.000156              0.001281
# 4636              0.792          0.000500              0.021906
# 4637              0.792          0.000063              0.003531
# 4638              0.792          0.000219              0.003844
# 4639              0.792          0.000063              0.012000
#
#       REC_REGION_RATIO  SAME_SPG  SAME_SIGUNGU  SAME_REGION  SAME_INNB  \
# 0             0.155750         0             0            0          0
# 1             0.155750         0             0            0          0
# 2             0.220656         0             0            0          0
# 3             0.027312         0             0            0          0
# 4             0.028469         0             0            0          0
# ...                ...       ...           ...          ...        ...
# 4635          0.035562         0             0            0          0
# 4636          0.065656         0             0            0          0
# 4637          0.024063         0             0            0          0
# 4638          0.220656         0             0            0          0
# 4639          0.028469         0             0            0          0
#
#       SAME_TOTAL
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 4635           0
# 4636           0
# 4637           0
# 4638           0
# 4639           0
#
# [4640 rows x 26 columns]

# %%
train.drop(columns=['INVC_CONT'],inplace=True)

# %%
train_ratio = train.iloc[:,11:21]
test_ratio = test.iloc[:,11:21]

# %%
train = pd.read_csv('features.csv')
test = pd.read_csv('features_te.csv')

# %%
train = pd.concat([train,train_ratio],axis=1)
test = pd.concat([test,test_ratio],axis=1)

# %%
train = train.fillna(0)
test = test.fillna(0)

# %%
train.drop(columns=['SEND_SPG_NM','SEND_SIGUNGU_NM','SEND_REGION','REC_SPG_NM','REC_SIGUNGU_NM','REC_REGION'],inplace=True)
test.drop(columns=['SEND_SPG_NM','SEND_SIGUNGU_NM','SEND_REGION','REC_SPG_NM','REC_SIGUNGU_NM','REC_REGION'],inplace=True)

train = pd.get_dummies(train)
test = pd.get_dummies(test)

# %%
train.to_csv('features_et.csv',index=False)
test.to_csv('features_et_te.csv',index=False)

# %%
train = pd.read_csv('features_et.csv')
test = pd.read_csv('features_et_te.csv')

# %% [markdown]
# # Modeling

# %% [markdown]
# #### ExtraTrees

# %%
clf = ExtraTreesRegressor(random_state=0, n_estimators = 400, bootstrap = True, max_features=5, n_jobs=-1)
scores = cross_val_score(clf, train, target, scoring='neg_mean_squared_error', cv=6)
print('교차 검증별 정확도:', np.round(scores, 4))
print('평균 검증 정확도:', np.round(np.mean(scores), 4))
print('RMSE:', np.sqrt(-np.mean(scores)))
# Out:
# 교차 검증별 정확도: [-29.6294 -34.3402 -22.574  -22.6183 -26.6302 -25.7449]
# 평균 검증 정확도: -26.9228
# RMSE: 5.188719469334962

# %%
clf.fit(train,target)
# Out:
# ExtraTreesRegressor(bootstrap=True, max_features=5, n_estimators=400, n_jobs=-1,
#                     random_state=0)

# %%
test_preds = clf.predict(test)

# %%
submission['INVC_CONT'] = test_preds
submission
# Out:
#       index  INVC_CONT
# 0     32000     5.7525
# 1     32001     5.8725
# 2     32002     5.3975
# 3     32003     5.7875
# 4     32004     5.2950
# ...     ...        ...
# 4635  36635     5.0125
# 4636  36636     5.2100
# 4637  36637     5.2425
# 4638  36638     4.7775
# 4639  36639     4.6075
#
# [4640 rows x 2 columns]

# %%
submission.describe()
# Out:
#               index    INVC_CONT
# count   4640.000000  4640.000000
# mean   34319.500000     4.821742
# std     1339.596954     3.124140
# min    32000.000000     3.230000
# 25%    33159.750000     3.645000
# 50%    34319.500000     4.551250
# 75%    35479.250000     5.335000
# max    36639.000000   147.030000

# %%
submission.to_csv('et_all_5features.csv',index=False)

# %% [markdown]
# # Ensemble

# %%
pred1 = pd.read_csv('cat_oof3.csv')
pred2 = pd.read_csv('et_all_5features.csv')

# %%
submission['INVC_CONT'] = pred1['INVC_CONT']*0.5 + pred2['INVC_CONT']*0.5
submission
# Out:
#       index  INVC_CONT
# 0     32000   5.127688
# 1     32001   5.598483
# 2     32002   5.198507
# 3     32003   5.480520
# 4     32004   5.380531
# ...     ...        ...
# 4635  36635   4.907058
# 4636  36636   4.962903
# 4637  36637   4.644369
# 4638  36638   4.571066
# 4639  36639   4.388698
#
# [4640 rows x 2 columns]

# %%
submission.describe()
# Out:
#               index    INVC_CONT
# count   4640.000000  4640.000000
# mean   34319.500000     4.668825
# std     1339.596954     3.035650
# min    32000.000000     3.347619
# 25%    33159.750000     3.628598
# 50%    34319.500000     4.499876
# 75%    35479.250000     5.117000
# max    36639.000000   148.276066

# %%
submission.to_csv('submission_ensemble1.csv',index=False)
